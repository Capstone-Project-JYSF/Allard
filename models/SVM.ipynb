# %%
from sklearn import svm
from sklearn.dummy import DummyRegressor
import pandas as pd
from sklearn.model_selection import (
    GridSearchCV,
    cross_val_score,
    cross_validate,
    train_test_split,
)
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import (
    ColumnTransformer,
    TransformedTargetRegressor,
    make_column_transformer,
)
import numpy as np

# %% [markdown]
# # Load data

# %%
data = pd.read_csv('../data/cleaned_data_v2.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 47 columns):
#  #   Column                                                                                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                         --------------  -----
#  0   case number                                                                                                                                                                                                                    696 non-null    object
#  1   Who was the member adjudicating the decision?                                                                                                                                                                                  696 non-null    object
#  2   What was the location of the landlord tenant board?                                                                                                                                                                            696 non-null    object
#  3   Did the decision state the landlord was represented?                                                                                                                                                                           696 non-null    int64
#  4   Did the decision state the landlord attended the hearing?                                                                                                                                                                      696 non-null    int64
#  5   Did the decision state the tenant was represented?                                                                                                                                                                             696 non-null    int64
#  6   Did the decision state the tenant attended the hearing?                                                                                                                                                                        696 non-null    int64
#  7   Did the decision state the landlord was a not-for-profit landlord (e.g. Toronto Community Housing)?                                                                                                                            696 non-null    int64
#  8   Did the decision state the tenant was collecting a subsidy?                                                                                                                                                                    696 non-null    int64
#  9   What was the outcome of the case?                                                                                                                                                                                              696 non-null    object
#  10  What was the length of the tenancy                                                                                                                                                                                             696 non-null    float64
#  11  What was the monthly rent?                                                                                                                                                                                                     696 non-null    float64
#  12  rental deposit amount                                                                                                                                                                                                          696 non-null    float64
#  13  was there an rent increases                                                                                                                                                                                                    696 non-null    int64
#  14  What was the total amount of arrears?                                                                                                                                                                                          696 non-null    float64
#  15  Over how many months did the arrears accumulate?                                                                                                                                                                               696 non-null    float64
#  16  Does the tenant made a payment on the arrears after the eviction notice                                                                                                                                                        696 non-null    int64
#  17  Did the decision mention a history of arrears by the tenant separate from the arrears in the current claim (more than one period of arrears, recurrently coming in and out of arrears, arrears with previous landlord, etc.)?  696 non-null    int64
#  18  Did the member find the tenant had or seemed to have the ability to pay rent, but chose not do so?                                                                                                                             696 non-null    int64
#  19  What were the specific mental, medical, or physical conditions of the tenant, if any?                                                                                                                                          696 non-null    int64
#  20  Did the decision state that the tenant had children living with them?                                                                                                                                                          696 non-null    int64
#  21  Was the tenant employed at the time of the hearing?                                                                                                                                                                            696 non-null    int64
#  22  If the tenant was not employed, did the decision state the tenant was receiving any form of government assistance (e.g. OW, childcare benefits, ODSP, OSAP)?                                                                   696 non-null    int64
#  23  If the tenant was employed, did the decision state any doubts about the stability of employment e.g. lack of guaranteed hours, contract work, etc.?                                                                            696 non-null    int64
#  24  Did the member find the tenant had sufficient income to pay rent?                                                                                                                                                              696 non-null    int64
#  25  Did the decision mention the tenant lost their job leading up to or during the period of the hearing?                                                                                                                          696 non-null    int64
#  26  Did the decision mention any other extenuating circumstances experienced by the tenant leading up to or during the period of the claim (e.g. hospitalization, death in the family, etc.)?                                      696 non-null    int64
#  27  Did the decision mention the tenant’s difficulty finding alternative housing for any reason e.g.physical limitations, reliance on social assistance, etc.?                                                                     696 non-null    int64
#  28  Did the decision state the tenant was given prior notice for the eviction?                                                                                                                                                     696 non-null    int64
#  29  Did the decisions state postponement would result in the tenant accruing additional arrears?                                                                                                                                   696 non-null    int64
#  30  Did the decision mention the validity of an N4 eviction notice?                                                                                                                                                                696 non-null    int64
#  31  Payment Plan                                                                                                                                                                                                                   696 non-null    float64
#  32  L1 present?                                                                                                                                                                                                                    696 non-null    int64
#  33  L2 present?                                                                                                                                                                                                                    696 non-null    int64
#  34  L3 present?                                                                                                                                                                                                                    696 non-null    int64
#  35  L4 present?                                                                                                                                                                                                                    696 non-null    int64
#  36  L8 present?                                                                                                                                                                                                                    696 non-null    int64
#  37  L9 present?                                                                                                                                                                                                                    696 non-null    int64
#  38  N5 present?                                                                                                                                                                                                                    696 non-null    int64
#  39  N6 present?                                                                                                                                                                                                                    696 non-null    int64
#  40  N7 present?                                                                                                                                                                                                                    696 non-null    int64
#  41  N8 present?                                                                                                                                                                                                                    696 non-null    int64
#  42  T1 present?                                                                                                                                                                                                                    696 non-null    int64
#  43  T2 present?                                                                                                                                                                                                                    696 non-null    int64
#  44  T3 present?                                                                                                                                                                                                                    696 non-null    int64
#  45  T5 present?                                                                                                                                                                                                                    696 non-null    int64
#  46  T6 present?                                                                                                                                                                                                                    696 non-null    int64
# dtypes: float64(6), int64(37), object(4)
# memory usage: 255.7+ KB

# %%
data = data.rename(columns={
    'What was the length of the tenancy, or in other words, how long had the tenants lived at the residence in question? '
    :'What was the length of the tenancy',
    'What was the amount of the rental deposit? ':'rental deposit amount',
    'If any rent increases occurred, what was the rent after the increase(s)?':'was there an rent increases',
    'Over how many months did the arrears accumulate? ':'Over how many months did the arrears accumulate?',
    'If the tenant made a payment on the arrears after the eviction notice was served and/or prior to the hearing, what was the amount of the payment? ':'Does the tenant made a payment on the arrears after the eviction notice',
    'What were the specific mental, medical, or physical conditions of the tenant, if any? ':'What were the specific mental, medical, or physical conditions of the tenant, if any?'})

# %%
train_df, test_df = train_test_split(data, test_size=0.2, random_state=123)
X_train, y_train = train_df.drop(columns = ["What was the outcome of the case?"]), train_df["What was the outcome of the case?"]
X_test, y_test = test_df.drop(columns = ["What was the outcome of the case?"]), test_df["What was the outcome of the case?"]
X_train.head()
# Out:
#       case number Who was the member adjudicating the decision?  \
# 195  TSL-90833-17                               roger rodrigues
# 553  TNL-07861-18                                  nancy morris
# 598  TSL-96267-18                                david mungovan
# 645  TEL-81094-17                               shelby whittick
# 634  TEL-80073-17                                  jim mcmaster
#
#     What was the location of the landlord tenant board?  \
# 195                                            Toronto
# 553                                            Toronto
# 598                                            Toronto
# 645                                             Whitby
# 634                                            Toronto
#
#      Did the decision state the landlord was represented?  \
# 195                                                  1
# 553                                                  0
# 598                                                  1
# 645                                                  0
# 634                                                  1
#
#      Did the decision state the landlord attended the hearing?  \
# 195                                                  0
# 553                                                  1
# 598                                                  0
# 645                                                  1
# 634                                                  1
#
#      Did the decision state the tenant was represented?  \
# 195                                                  0
# 553                                                  0
# 598                                                  0
# 645                                                  0
# 634                                                  0
#
#      Did the decision state the tenant attended the hearing?  \
# 195                                                  0
# 553                                                  1
# 598                                                  1
# 645                                                  1
# 634                                                  1
#
#      Did the decision state the landlord was a not-for-profit landlord (e.g. Toronto Community Housing)?  \
# 195                                                  0
# 553                                                  0
# 598                                                  0
# 645                                                  0
# 634                                                  0
#
#      Did the decision state the tenant was collecting a subsidy?  \
# 195                                                  0
# 553                                                  0
# 598                                                  0
# 645                                                  0
# 634                                                  0
#
#      What was the length of the tenancy  ...  L9 present?  N5 present?  \
# 195                            6.306049  ...            0            0
# 553                           24.000000  ...            0            0
# 598                            6.306049  ...            0            0
# 645                            6.306049  ...            0            0
# 634                            6.306049  ...            0            0
#
#      N6 present?  N7 present?  N8 present?  T1 present?  T2 present?  \
# 195            0            0            0            0            0
# 553            0            0            0            0            0
# 598            0            0            0            0            0
# 645            0            0            0            0            0
# 634            0            0            0            0            1
#
#      T3 present?  T5 present?  T6 present?
# 195            0            0            0
# 553            0            0            0
# 598            0            0            0
# 645            0            0            0
# 634            0            0            0
#
# [5 rows x 46 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 556 entries, 195 to 510
# Data columns (total 46 columns):
#  #   Column                                                                                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                         --------------  -----
#  0   case number                                                                                                                                                                                                                    556 non-null    object
#  1   Who was the member adjudicating the decision?                                                                                                                                                                                  556 non-null    object
#  2   What was the location of the landlord tenant board?                                                                                                                                                                            556 non-null    object
#  3   Did the decision state the landlord was represented?                                                                                                                                                                           556 non-null    int64
#  4   Did the decision state the landlord attended the hearing?                                                                                                                                                                      556 non-null    int64
#  5   Did the decision state the tenant was represented?                                                                                                                                                                             556 non-null    int64
#  6   Did the decision state the tenant attended the hearing?                                                                                                                                                                        556 non-null    int64
#  7   Did the decision state the landlord was a not-for-profit landlord (e.g. Toronto Community Housing)?                                                                                                                            556 non-null    int64
#  8   Did the decision state the tenant was collecting a subsidy?                                                                                                                                                                    556 non-null    int64
#  9   What was the length of the tenancy                                                                                                                                                                                             556 non-null    float64
#  10  What was the monthly rent?                                                                                                                                                                                                     556 non-null    float64
#  11  rental deposit amount                                                                                                                                                                                                          556 non-null    float64
#  12  was there an rent increases                                                                                                                                                                                                    556 non-null    int64
#  13  What was the total amount of arrears?                                                                                                                                                                                          556 non-null    float64
#  14  Over how many months did the arrears accumulate?                                                                                                                                                                               556 non-null    float64
#  15  Does the tenant made a payment on the arrears after the eviction notice                                                                                                                                                        556 non-null    int64
#  16  Did the decision mention a history of arrears by the tenant separate from the arrears in the current claim (more than one period of arrears, recurrently coming in and out of arrears, arrears with previous landlord, etc.)?  556 non-null    int64
#  17  Did the member find the tenant had or seemed to have the ability to pay rent, but chose not do so?                                                                                                                             556 non-null    int64
#  18  What were the specific mental, medical, or physical conditions of the tenant, if any?                                                                                                                                          556 non-null    int64
#  19  Did the decision state that the tenant had children living with them?                                                                                                                                                          556 non-null    int64
#  20  Was the tenant employed at the time of the hearing?                                                                                                                                                                            556 non-null    int64
#  21  If the tenant was not employed, did the decision state the tenant was receiving any form of government assistance (e.g. OW, childcare benefits, ODSP, OSAP)?                                                                   556 non-null    int64
#  22  If the tenant was employed, did the decision state any doubts about the stability of employment e.g. lack of guaranteed hours, contract work, etc.?                                                                            556 non-null    int64
#  23  Did the member find the tenant had sufficient income to pay rent?                                                                                                                                                              556 non-null    int64
#  24  Did the decision mention the tenant lost their job leading up to or during the period of the hearing?                                                                                                                          556 non-null    int64
#  25  Did the decision mention any other extenuating circumstances experienced by the tenant leading up to or during the period of the claim (e.g. hospitalization, death in the family, etc.)?                                      556 non-null    int64
#  26  Did the decision mention the tenant’s difficulty finding alternative housing for any reason e.g.physical limitations, reliance on social assistance, etc.?                                                                     556 non-null    int64
#  27  Did the decision state the tenant was given prior notice for the eviction?                                                                                                                                                     556 non-null    int64
#  28  Did the decisions state postponement would result in the tenant accruing additional arrears?                                                                                                                                   556 non-null    int64
#  29  Did the decision mention the validity of an N4 eviction notice?                                                                                                                                                                556 non-null    int64
#  30  Payment Plan                                                                                                                                                                                                                   556 non-null    float64
#  31  L1 present?                                                                                                                                                                                                                    556 non-null    int64
#  32  L2 present?                                                                                                                                                                                                                    556 non-null    int64
#  33  L3 present?                                                                                                                                                                                                                    556 non-null    int64
#  34  L4 present?                                                                                                                                                                                                                    556 non-null    int64
#  35  L8 present?                                                                                                                                                                                                                    556 non-null    int64
#  36  L9 present?                                                                                                                                                                                                                    556 non-null    int64
#  37  N5 present?                                                                                                                                                                                                                    556 non-null    int64
#  38  N6 present?                                                                                                                                                                                                                    556 non-null    int64
#  39  N7 present?                                                                                                                                                                                                                    556 non-null    int64
#  40  N8 present?                                                                                                                                                                                                                    556 non-null    int64
#  41  T1 present?                                                                                                                                                                                                                    556 non-null    int64
#  42  T2 present?                                                                                                                                                                                                                    556 non-null    int64
#  43  T3 present?                                                                                                                                                                                                                    556 non-null    int64
#  44  T5 present?                                                                                                                                                                                                                    556 non-null    int64
#  45  T6 present?                                                                                                                                                                                                                    556 non-null    int64
# dtypes: float64(6), int64(37), object(3)
# memory usage: 204.2+ KB

# %%
y_train.value_counts()
# Out:
# No relief            352
# Relief               200
# Conditional Order      4
# Name: What was the outcome of the case?, dtype: int64

# %% [markdown]
# there is an imbalanced class: 352's No relief and 124's Postponement of eviction and others. Therefore, we should add `class_weight = 'balanced'` in estimator's parameter.

# %%
X_train['If the tenant was employed, did the decision state any doubts about the stability of employment e.g. lack of guaranteed hours, contract work, etc.?'].unique()
# Out:
# array([ 0,  1, -1], dtype=int64)

# %% [markdown]
# ## Preprocess data with pipeline

# %%
categorical_features = ['Who was the member adjudicating the decision?',
                        'What was the location of the landlord tenant board?'
                        ]

numeric_features = [
'What was the length of the tenancy',
'What was the monthly rent?',
'rental deposit amount',
'What was the total amount of arrears?',
'Over how many months did the arrears accumulate?',

]
ordinal_features = [
'Was the tenant employed at the time of the hearing?',
'Payment Plan',
'If the tenant was not employed, did the decision state the tenant was receiving any form of government assistance (e.g. OW, childcare benefits, ODSP, OSAP)?',
'If the tenant was employed, did the decision state any doubts about the stability of employment e.g. lack of guaranteed hours, contract work, etc.?'
]
drop_features = ['case number']
ordering_ordinal = [
    [-1,0,1],
    [0, 0.5, 1],
    [ -1, 0, 1],
    [ -1, 0, 1]
]

passthrough_feats = list(
    set(X_train.columns)
    - set(categorical_features)
    - set(numeric_features)
    - set(ordinal_features)
    - set(drop_features)
)

# %%
preprocessor = make_column_transformer(
        (OneHotEncoder(handle_unknown="ignore"),categorical_features),
        ("passthrough", passthrough_feats),
        (StandardScaler(),numeric_features),
        (OrdinalEncoder(categories = ordering_ordinal),ordinal_features),
        ("drop",drop_features))
preprocessor
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['Who was the member adjudicating the '
#                                   'decision?',
#                                   'What was the location of the landlord '
#                                   'tenant board?']),
#                                 ('passthrough', 'passthrough',
#                                  ['was there an rent increases', 'T1 present?',
#                                   'L2 present?', 'L4 present?', 'T5 present?',
#                                   'Did the decision state the tenant attended '
#                                   'the hearing?',
#                                   'T2 pres...
#                                  ['Was the tenant employed at the time of the '
#                                   'hearing?',
#                                   'Payment Plan',
#                                   'If the tenant was not employed, did the '
#                                   'decision state the tenant was receiving any '
#                                   'form of government assistance (e.g. OW, '
#                                   'childcare benefits, ODSP, OSAP)?',
#                                   'If the tenant was employed, did the '
#                                   'decision state any doubts about the '
#                                   'stability of employment e.g. lack of '
#                                   'guaranteed hours, contract work, etc.?']),
#                                 ('drop', 'drop', ['case number'])])

# %% [markdown]
# ## Baseline model

# %%
results = {}
scoring_metrics = ["accuracy"]

# %%
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" % (mean_scores[i], std_scores[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %%
from sklearn.dummy import DummyClassifier
results["dummy"] = mean_std_cross_val_scores(
    DummyClassifier(), X_train, y_train, return_train_score=True,scoring = scoring_metrics
)
pd.DataFrame(results).T
# Out:
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
#                 fit_time         score_time      test_accuracy  \
# dummy  0.002 (+/- 0.000)  0.001 (+/- 0.001)  0.633 (+/- 0.004)
#
#           train_accuracy
# dummy  0.633 (+/- 0.001)

# %% [markdown]
# ### Linear SVM

# %%
pipe = make_pipeline(preprocessor,svm.LinearSVC())


results["Linear_SVC"] = mean_std_cross_val_scores(
    pipe, X_train, y_train, return_train_score=True, scoring=scoring_metrics
)
pd.DataFrame(results).T
# Out:
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#                      fit_time         score_time      test_accuracy  \
# dummy       0.002 (+/- 0.000)  0.001 (+/- 0.001)  0.633 (+/- 0.004)
# Linear_SVC  0.150 (+/- 0.029)  0.033 (+/- 0.023)  0.754 (+/- 0.046)
#
#                train_accuracy
# dummy       0.633 (+/- 0.001)
# Linear_SVC  0.862 (+/- 0.012)

# %% [markdown]
# ### Hyperparameter tuning
# Use randomizedSearchCV to find the best C parameters value.

# %%
from scipy.stats import loguniform
from sklearn.model_selection import RandomizedSearchCV


linear_svc=svm.LinearSVC(random_state=123,max_iter=1000)
pipe_linear_svc=make_pipeline(preprocessor,linear_svc)

param_dist = { 
    "linearsvc__C": loguniform(1e-3, 1e3),
    "linearsvc__class_weight": ["balanced", None],
    "linearsvc__multi_class": ["ovr","crammer_singer"]
}

random_search = RandomizedSearchCV(
            pipe_linear_svc, param_distributions=param_dist, n_iter=20, 
            n_jobs=-1, verbose = 1, scoring= scoring_metrics, 
            refit = 'accuracy', return_train_score=True, random_state=123)

random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# RandomizedSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(transformers=[('onehotencoder',
#                                                                                OneHotEncoder(handle_unknown='ignore'),
#                                                                                ['Who '
#                                                                                 'was '
#                                                                                 'the '
#                                                                                 'member '
#                                                                                 'adjudicating '
#                                                                                 'the '
#                                                                                 'decision?',
#                                                                                 'What '
#                                                                                 'was '
#                                                                                 'the '
#                                                                                 'location '
#                                                                                 'of '
#                                                                                 'the '
#                                                                                 'landlord '
#                                                                                 'tenant '
#                                                                                 'board?']),
#                                                                               ('passthrough',
#                                                                                'passthrough',
#                                                                                ['was '
#                                                                                 'there '
#                                                                                 'an '
#                                                                                 'rent '
#                                                                                 'increases',
#                                                                                 'T1 '
#                                                                                 'present?...
#                                               LinearSVC(random_state=123))]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'linearsvc__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002B8F8E5FE80>,
#                                         'linearsvc__class_weight': ['balanced',
#                                                                     None],
#                                         'linearsvc__multi_class': ['ovr',
#                                                                    'crammer_singer']},
#                    random_state=123, refit='accuracy', return_train_score=True,
#                    scoring=['accuracy'], verbose=1)

# %%
random_search.best_params_
# Out:
# {'linearsvc__C': 0.35890684548321944,
#  'linearsvc__class_weight': 'balanced',
#  'linearsvc__multi_class': 'crammer_singer'}

# %%
random_search.best_score_
# Out:
# 0.7627413127413127

# %%
linear_svc_2=svm.LinearSVC(random_state=123,C=0.35890684548321944,class_weight="balanced",multi_class="crammer_singer",max_iter=1000) 
pipe_linear_svc_2=make_pipeline(preprocessor,linear_svc_2)

results["Linear_SVC_Best"] = mean_std_cross_val_scores(
    pipe_linear_svc_2, X_train, y_train, return_train_score=True, scoring=scoring_metrics
)
pd.DataFrame(results).T
# Out:
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#                           fit_time         score_time      test_accuracy  \
# dummy            0.002 (+/- 0.000)  0.001 (+/- 0.001)  0.633 (+/- 0.004)
# Linear_SVC       0.150 (+/- 0.029)  0.033 (+/- 0.023)  0.754 (+/- 0.046)
# Linear_SVC_Best  0.074 (+/- 0.024)  0.011 (+/- 0.004)  0.763 (+/- 0.058)
#
#                     train_accuracy
# dummy            0.633 (+/- 0.001)
# Linear_SVC       0.862 (+/- 0.012)
# Linear_SVC_Best  0.836 (+/- 0.015)

# %% [markdown]
# ## Feature Importance

# %%
pipe_linear_svc_2.fit(X_train, y_train)
# Out:
# c:\Users\Francesco\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Who was the member '
#                                                    'adjudicating the decision?',
#                                                    'What was the location of '
#                                                    'the landlord tenant '
#                                                    'board?']),
#                                                  ('passthrough', 'passthrough',
#                                                   ['was there an rent '
#                                                    'increases',
#                                                    'T1 present?', 'L2 present?',
#                                                    'L4 present?', 'T5 present?',
#                                                    'Did the decision sta...
#                                                    'government assistance '
#                                                    '(e.g. OW, childcare '
#                                                    'benefits, ODSP, OSAP)?',
#                                                    'If the tenant was '
#                                                    'employed, did the decision '
#                                                    'state any doubts about the '
#                                                    'stability of employment '
#                                                    'e.g. lack of guaranteed '
#                                                    'hours, contract work, '
#                                                    'etc.?']),
#                                                  ('drop', 'drop',
#                                                   ['case number'])])),
#                 ('linearsvc',
#                  LinearSVC(C=0.35890684548321944, class_weight='balanced',
#                            multi_class='crammer_singer', random_state=123))])

# %%
column_names = (
    pipe_linear_svc_2.named_steps['columntransformer'].named_transformers_['onehotencoder'].get_feature_names_out(categorical_features).tolist()
    + passthrough_feats    
    + numeric_features
    + ordinal_features
)
len(column_names)
# Out:
# 126

# %%
pipe_linear_svc_2.named_steps["linearsvc"].coef_.shape
# Out:
# (3, 126)

# %%
def squared_coef(coefs):
    """ 
    For each feature,  calculated the squared-coefficient of each
    feature by adding together the squared values of the feature's coefficient
    for each class.
    """
    squared_coef = np.square(coefs)
    results = np.sum(squared_coef, axis=0)
    return results

# %%
squared_coef(pipe_linear_svc_2.named_steps['linearsvc'].coef_).shape
# Out:
# (126,)

# %%
coefs= (
    pd.DataFrame(squared_coef(pipe_linear_svc_2.named_steps["linearsvc"].coef_), column_names, columns=["coef"]) # check first classifier
    .query("coef != 0")
    .sort_values("coef",ascending=False)
    .reset_index()
    .rename(columns={"index": "variable"})
)
# coefs.style.background_gradient('PuOr')

# %%
coefs
# Out:
#                                               variable          coef
# 0    What was the location of the landlord tenant b...  1.134795e+00
# 1    Did the decision mention the tenant’s difficul...  6.235867e-01
# 2    Did the decision state the tenant was represen...  6.037648e-01
# 3    What were the specific mental, medical, or phy...  6.019093e-01
# 4    Who was the member adjudicating the decision?_...  5.743243e-01
# ..                                                 ...           ...
# 117  Who was the member adjudicating the decision?_...  3.641211e-34
# 118  Who was the member adjudicating the decision?_...  2.337030e-34
# 119  Who was the member adjudicating the decision?_...  6.808463e-35
# 120                                        L4 present?  6.211312e-35
# 121  Who was the member adjudicating the decision?_...  3.686350e-35
#
# [122 rows x 2 columns]

# %%
import altair as alt

alt.Chart(
    coefs,
    title=pipe_linear_svc_2.named_steps["linearsvc"].__str__()[:-2] + " Coefficients",
).mark_bar().encode(y=alt.Y("variable", sort="-x"), x="coef")
# Out:
# alt.Chart(...)
